# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadIrsyadDany/MachineLearning_2024/blob/main/Pertemuan%207/tugas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('Mall_Customers.csv')

df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# 2.   Tentukan fitur apa yang tepat untuk melakukan clustering (minimal 2)

# %%
# Seleksi Fitur
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]
X.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0                  15                      39
# 1                  15                      81
# 2                  16                       6
# 3                  16                      77
# 4                  17                      40

# %%
# Plot Data
# Karena data 4 dimensi, maka akan kita coba
# plot cluster berdasarkan Annual Income dan SPending Score  saja
plt.scatter(X['Annual Income (k$)'], X['Spending Score (1-100)'])

# %% [markdown]
# 3. Buatlah model K-Means dengan mempertimbangkan jumlah kk yang terbaik.

# %%
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)

# Plot SSE terhadap jumlah cluster
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), sse, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.show()

# %%
# Cek Nilai SSE setiap k
for idx, sse_val in enumerate(sse, start=1):
    print(f'k={idx}; SSE={sse_val}')
# Out:
# k=1; SSE=269981.28000000014
# k=2; SSE=183653.3289473683
# k=3; SSE=106348.37306211119
# k=4; SSE=73880.64496247198
# k=5; SSE=44448.45544793369
# k=6; SSE=40825.16946386947
# k=7; SSE=33642.57922077922
# k=8; SSE=26686.837785187785
# k=9; SSE=24766.471609793436
# k=10; SSE=23103.122085983905

# %% [markdown]
# 4. Buatlah implementasi model SOM untuk segmentasi citra lain
